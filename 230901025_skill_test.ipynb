# %%
#1A
import statistics

#Sample exam scores (replace with your actual data)
exam_scores = [78, 65, 92, 88, 55, 72, 98, 60, 80, 75, 58, 82, 95, 70, 68, 85, 77, 63, 90, 89]

# 1. Overall Class Performance
average_score = statistics.mean(exam_scores)
highest_score = max(exam_scores)
lowest_score = min(exam_scores)

print(f"Average Score: {average_score:.2f}")
print(f"Highest Score: {highest_score}")
print(f"Lowest Score: {lowest_score}")

# 2. Pass/Fail Classification
pass_mark = 50
passed_students = [score for score in exam_scores if score >= pass_mark]
failed_students = [score for score in exam_scores if score < pass_mark]

print(f"\nNumber of students who passed: {len(passed_students)}")
print(f"Number of students who failed: {len(failed_students)}")

# 3. Grading on a Curve (example using fixed thresholds)
def get_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    elif score >= 50:
        return "E"
    else:
        return "F"

print("\nStudent Grades:")
for score in exam_scores:
    grade = get_grade(score)
    print(f"Score: {score}, Grade: {grade}")
# Out:
# Average Score: 77.00
# Highest Score: 98
# Lowest Score: 55
#
# Number of students who passed: 20
# Number of students who failed: 0
#
# Student Grades:
# Score: 78, Grade: C
# Score: 65, Grade: D
# Score: 92, Grade: A
# Score: 88, Grade: B
# Score: 55, Grade: E
# Score: 72, Grade: C
# Score: 98, Grade: A
# Score: 60, Grade: D
# Score: 80, Grade: B
# Score: 75, Grade: C
# Score: 58, Grade: E
# Score: 82, Grade: B
# Score: 95, Grade: A
# Score: 70, Grade: C
# Score: 68, Grade: D
# Score: 85, Grade: B
# Score: 77, Grade: C
# Score: 63, Grade: D
# Score: 90, Grade: A
# Score: 89, Grade: B

# %%
#1B
import numpy as np

#Input 2x2 matrix A
print("Enter the elements of 2x2 matrix A row-wise:")

A = []
for i in range(2):
    row = list(map(float, input(f"Row {i+1} (enter 2 numbers separated by space): ").split()))
    if len(row) != 2:
        raise ValueError("Each row must contain exactly 2 numbers.")
    A.append(row)

A = np.array(A)

#Input 2x1 vector b
print("Enter the elements of 2x1 vector b:")
b = []
for i in range(2):
    val = float(input(f"Element {i+1}: "))
    b.append(val)

b = np.array(b)

try:
    x = np.linalg.solve(A, b)
    print("\nThe solution vector x is:")
    print(x)
except np.linalg.LinAlgError:
    print("\nThe system has no unique solution (matrix might be singular).")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 2
#       1 #1B
# ----> 2 import numpy as np
#       4 #Input 2x2 matrix A
#       5 print("Enter the elements of 2x2 matrix A row-wise:")
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#2A
import numpy as np
import matplotlib.pyplot as plt

#User input for 30 days of step count
print("Enter your daily step counts for the past 30 days:")

steps = []
for i in range(30):
    while True:
        try:
            count = int(input(f"Day {i+1} steps: "))
            if count < 0:
                raise ValueError
            steps.append(count)
            break
        except ValueError:
            print("Please enter a valid non-negative integer.")

steps = np.array(steps)

total_steps = np.sum(steps)
average_steps = np.mean(steps)
max_steps = np.max(steps)
min_steps = np.min(steps)

print("\nStep Count Summary (Past 30 Days):")
print(f"Total steps: {total_steps}")
print(f"Average steps/day: {average_steps:.2f}")
print(f"Maximum steps in a day: {max_steps}")
print(f"Minimum steps in a day: {min_steps}")

threshold = 9000
high_activity_days = np.where(steps > threshold)[0] + 1
print(f"\nDays with high activity (>{threshold} steps): {high_activity_days.tolist()}")

if len(steps) >= 5:
    moving_avg = np.convolve(steps, np.ones(5)/5, mode='valid')

    plt.figure(figsize=(12, 6))
    plt.title('Daily Step Count Analysis (Last 30 Days)')
    plt.xlabel('Day')
    plt.ylabel('Steps')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Not enough data for trend analysis.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 #2A
# ----> 2 import numpy as np
#       3 import matplotlib.pyplot as plt
#       5 #User input for 30 days of step count
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#2B
import numpy as np
import matplotlib.pyplot as plt

print("Enter the grades of 30 students for Math, Science, and English.")
print("Each entry should be 3 space-separated integers (e.g., 85 90 78)")

grades = []
for i in range(30):
    while True:
        try:
            entry = list(map(int, input(f"Student {i+1} grades: ").split()))
            if len(entry) != 3 or not all(0 <= x <= 100 for x in entry):
                raise ValueError
            grades.append(entry)
            break
        except ValueError:
            print("Invalid input. Please enter 3 integers between 0 and 100.")

grades = np.array(grades)  # Shape: (30, 3)
subjects = ['Math', 'Science', 'English']


print("\nSubject-wise Statistics:")
for i, subject in enumerate(subjects):
    subject_grades = grades[:, i]
    print(f"{subject}:")
    print(f"  Average: {np.mean(subject_grades):.2f}")
    print(f"  Highest: {np.max(subject_grades)}")
    print(f"  Lowest : {np.min(subject_grades)}")


total_scores = np.sum(grades, axis=1)
average_scores = np.mean(grades, axis=1)

top_index = np.argmax(total_scores)
print("\nTop Performing Student:")
print(f"  Student {top_index+1} -> Total: {total_scores[top_index]}, Average: {average_scores[top_index]:.2f}")

plt.figure(figsize=(12, 5))

for i, subject in enumerate(subjects):
    plt.subplot(1, 3, i+1)
    plt.hist(grades[:, i], bins=10, edgecolor='black', alpha=0.7)
    plt.title(f'{subject} Grade Distribution')
    plt.xlabel('Grade')
    plt.ylabel('Number of Students')
    plt.grid(True)

plt.tight_layout()
plt.show()

plt.figure(figsize=(6, 4))
avg_subject_scores = np.mean(grades, axis=0)
plt.bar(subjects, avg_subject_scores, color=['blue', 'green', 'orange'])
plt.title('Average Score per Subject')
plt.ylabel('Average Score')
plt.ylim(0, 100)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# Enter the elements of 2x2 matrix A row-wise:
# Row 1 (enter 2 numbers separated by space): 2 9
# Row 2 (enter 2 numbers separated by space): 2 6
# Enter the elements of 2x1 vector b:
# Element 1: 3 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-0f4268d3cee3> in <cell line: 0>()
#      17 b = []
#      18 for i in range(2):
# ---> 19     val = float(input(f"Element {i+1}: "))
#      20     b.append(val)
#      21
#
# ValueError: could not convert string to float: '3 1'

# %%
#3A
import cmath

def get_impedance(component_type, value, frequency):
    omega = 2 * cmath.pi * frequency
    if component_type == 'R':
        return complex(value)
    elif component_type == 'C':
        return complex(0, -1 / (omega * value))
    elif component_type == 'L':
        return complex(0, omega * value)
    else:
        raise ValueError("Invalid component type. Must be 'R', 'L', or 'C'.")

def compute_total_impedance(impedance_list, configuration):
    if configuration == 'series':
        return sum(impedance_list)
    elif configuration == 'parallel':
        inv_total = sum(1 / z for z in impedance_list)
        return 1 / inv_total if inv_total != 0 else complex('inf')
    else:
        raise ValueError("Invalid configuration. Must be 'series' or 'parallel'.")

def main():
    print("=== Total Impedance Calculator ===")
    
    try:
        frequency = float(input("Enter the frequency of the AC source (in Hz): "))
        num_components = int(input("Enter the number of components: "))
        
        components = []
        for i in range(num_components):
            ctype = input(f"Enter type of component #{i+1} (R/L/C): ").strip().upper()
            value = float(input(f"Enter the value (Ohms for R, Henry for L, Farads for C): "))
            impedance = get_impedance(ctype, value, frequency)
            components.append(impedance)
            print(f"  Impedance of component #{i+1} ({ctype}) = {impedance:.2f} Ω")
        
        config = input("Enter the configuration (series/parallel): ").strip().lower()
        total = compute_total_impedance(components, config)
        
        print(f"\nTotal impedance of the circuit ({config}): {total:.2f} Ω")
    except Exception as e:
        print("Error:", e)

if _name_ == "_main_":
    main()

# %%
#3B
import numpy as np

print("Enter daily price data for STOCK A (Open, High, Low) for 5 days:")
stock_a = []
for i in range(5):
    while True:
        try:
            row = list(map(float, input(f"Day {i+1} (Open High Low): ").split()))
            if len(row) != 3:
                raise ValueError
            stock_a.append(row)
            break
        except ValueError:
            print("Invalid input. Please enter 3 numbers (Open High Low).")

print("\nEnter daily price data for STOCK B (Open, High, Low) for 5 days:")
stock_b = []
for i in range(5):
    while True:
        try:
            row = list(map(float, input(f"Day {i+1} (Open High Low): ").split()))
            if len(row) != 3:
                raise ValueError
            stock_b.append(row)
            break
        except ValueError:
            print("Invalid input. Please enter 3 numbers (Open High Low).")

stock_a = np.array(stock_a)
stock_b = np.array(stock_b)


sum_matrix = stock_a + stock_b
diff_matrix = stock_a - stock_b


print("\nElement-wise Sum of Stock A and B (Combined Price Values):")
print(sum_matrix)

print("\nElement-wise Difference of Stock A and B (Daily Spread):")
print(diff_matrix)

# %%
#4A
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_path = input("Enter the path to the EEG CSV data file: ")
df = pd.read_csv(file_path)

print("\nFirst few rows of the data:")
print(df.head())


participants = {}
for col in df.columns:
    if '_' in col:
        pid, eid = col.split('_')
        if pid not in participants:
            participants[pid] = []
        participants[pid].append(col)

print("\n--- Statistical Analysis ---")
for pid, electrodes in participants.items():
    print(f"\nParticipant: {pid}")
    for electrode in electrodes:
        signal = df[electrode]
        print(f"  Electrode {electrode}:")
        print(f"    Mean     : {signal.mean():.3f}")
        print(f"    Variance : {signal.var():.3f}")
        print(f"    Peak (Max): {signal.max():.3f}")

plot_choice = input("\nWould you like to visualize brainwave activity? (y/n): ").strip().lower()
if plot_choice == 'y':
    for pid, electrodes in participants.items():
        plt.figure(figsize=(10, 6))
        for electrode in electrodes:
            plt.plot(df[electrode], label=electrode)
        plt.title(f'EEG Signals for {pid}')
        plt.xlabel('Time Points')
        plt.ylabel('Brainwave Activity')
        plt.legend()
        plt.grid(True)
        plt.tight_layout()
        plt.show()

# %%
#4B
import pandas as pd
import matplotlib.pyplot as plt

data = {
    'Product': ['Laptop', 'Smartphone', 'Tablet', 'Monitor', 'Keyboard'],
    'Price': [1200, 800, 300, 150, 50],
    'Quantity': [10, 20, 15, 25, 50]
}

df = pd.DataFrame(data)


print("1. Inventory Data:")
print(df)

df['Total_Value'] = df['Price'] * df['Quantity']
print("\n2. Data with Total Value:")
print(df)


most_expensive = df.loc[df['Price'].idxmax()]
print("\n3. Most Expensive Product:")
print(most_expensive)

total_inventory_value = df['Total_Value'].sum()
print("\n4. Total Inventory Value:", total_inventory_value)


high_stock = df[df['Quantity'] > 20]
print("\n5. Products with quantity > 20:")
print(high_stock)


plt.figure(figsize=(8, 5))
plt.bar(df['Product'], df['Total_Value'], color='skyblue')
plt.title('Total Value of Inventory per Product')
plt.xlabel('Product')
plt.ylabel('Total Value ($)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
# Out:
# 1. Inventory Data:
#       Product  Price  Quantity
# 0      Laptop   1200        10
# 1  Smartphone    800        20
# 2      Tablet    300        15
# 3     Monitor    150        25
# 4    Keyboard     50        50
#
# 2. Data with Total Value:
#       Product  Price  Quantity  Total_Value
# 0      Laptop   1200        10        12000
# 1  Smartphone    800        20        16000
# 2      Tablet    300        15         4500
# 3     Monitor    150        25         3750
# 4    Keyboard     50        50         2500
#
# 3. Most Expensive Product:
# Product        Laptop
# Price            1200
# Quantity           10
# Total_Value     12000
# Name: 0, dtype: object
#
# 4. Total Inventory Value: 38750
#
# 5. Products with quantity > 20:
#     Product  Price  Quantity  Total_Value
# 3   Monitor    150        25         3750
# 4  Keyboard     50        50         2500

# %%
#5A
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv("sales_data.csv")

print("First 5 rows of the dataset:")
print(df.head())

print("\nMissing values in each column:")
print(df.isnull().sum())

if 'date' in df.columns:
   
df = df.dropna(subset=['date'])

numeric_cols = df.select_dtypes(include='number').columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())


df['month'] = df['date'].dt.to_period('M').astype(str)
monthly_sales = df.groupby('month')['sales'].sum().reset_index()

plt.figure(figsize=(12, 6))
plt.plot(monthly_sales['month'], monthly_sales['sales'], marker='o', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show(
# Out:
#   File "<ipython-input-1-32ad5244102e>", line 1
#     mport numpy as np
#           ^
# SyntaxError: invalid syntax

# %%
#5B
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("healthcare_data.csv")

print("Column names and data types:")
print(df.dtypes)

if 'age' in df.columns:
    avg_age = df['age'].mean()
    print(f"\nAverage age of patients: {avg_age:.2f} years")
else:
    print("\nColumn 'age' not found in dataset.")

if 'diagnosis' in df.columns:
    diagnosis_counts = df['diagnosis'].value_counts()
    print("\nDiagnosis distribution (top 10):")
    print(diagnosis_counts.head(10))

    plt.figure(figsize=(12, 6))
    diagnosis_counts.head(10).plot(kind='bar')
    plt.title('Top 10 Most Common Diagnoses')
    plt.xlabel('Diagnosis')
    plt.ylabel('Number of Patients')
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
else:
    print("\nColumn 'diagnosis' not found in dataset.")
# Out:
#    name  mark
# 0     A    90
# 1     B    76
# 2     C    88
# 3     D    95
# 4     E    59
# 5     F    71
# 6     G    63
# 7     H    48
# 8     I    55
# 9     J    39
# 10    K    65
# 11    L    87
# 12    M    96
# 13    N    98
# 14    O    54
# 15    P    86
# 16    Q    77
# 17    R    66
# 18    S    48
# 19    T    97
# Overall Class Performance:
# Average:       mark
# mean  72.9
# Highest mark:      mark
# max    98
# Lowest mark:      mark
# min    39
# Pass/Fail classification:
# Students who passed:
#     name  mark
# 0     A  90.0
# 1     B  76.0
# 2     C  88.0
# 3     D  95.0
# 4     E  59.0
# 5     F  71.0
# 6     G  63.0
# 8     I  55.0
# 10    K  65.0
# 11    L  87.0
# 12    M  96.0
# 13    N  98.0
# 14    O  54.0
# 15    P  86.0
# 16    Q  77.0
# 17    R  66.0
# 19    T  97.0
# Students who failed:
#     name  mark
# 7     H  48.0
# 9     J  39.0
# 18    S  48.0
